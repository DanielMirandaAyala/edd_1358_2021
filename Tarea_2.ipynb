# %% [markdown]
# <a href="https://colab.research.google.com/github/DanielMirandaAyala/edd_1358_2021/blob/master/Tarea_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class empleado:
    def __init__(self, num, nom, pat, mat, he, sb, anio):
        self.__num_trabajador= num
        self.__nombres= nom
        self.__apellido_paterno= pat
        self.__apellido_materno= mat
        self.__horas_extra= he
        self.__salario_base= sb
        self.__anio_ingreso= anio
  
    #get y set
    def get_num_Trabajador(self):
        return self.__num_trabajador

    def set_num_Trabajador(self, num):
        self.__num_trabajador= num
        return num
    def get_nombres(self):
        return self.__nombres

    def set_nombres(self, nom):
        self.__nombres= nom
        return nom

    def get_apellido_paterno(self):
        return self.__apellido_paterno

    def set_apellido_paterno(self, pat):
        self.__apellido_paterno= pat
        return pat

    def get_apellido_materno(self):
        return self.__apellido_materno

    def set_apellido_materno(self, mat):
        self.__apellido_materno= mat
        return mat

    def get_horas_extra(self):
        return self.__horas_extra

    def set_horas_extra(self, he):
        self.__horas_extra=he
        return he

    def get_salario_base(self):
        return self.__salario_base

    def set_salario_base(self, sb):
        self.__salario_base=sb
        return sb

    def get_anio_ingreso(self):
        return self.__anio_ingreso

    def set_anio_ingreso(self, anio):
        self.get_anio_ingreso=anio
        return anio

# %%
class Sueldos:
  def __init__(self):
    self.__data= None

  def cargar_datos(self, ruta_archivo):
    archivo = open(ruta_archivo, 'rt', encoding='latin1')
    cabeceras = archivo.readline()
    lineas = archivo.readlines()
    archivo.close()
    self.__data=Array( len(lineas) -1)
    
    #tarea
    datos_trabajadores = []

    #separar campos y hacer casting
    for linea in lineas:
      linea = linea.split(',')
      linea[0] = int(linea[0])
      linea[4] = int(linea[4])
      linea[5] = int(linea[5])
      anio = linea[6]
      anio = int(anio)
      linea[6] = anio
      #print(linea)
      datos_trabajadores.append(linea[0])
      
      #crear un objeto
      trabajador = empleado(linea[0],linea[1],linea[2],linea[3],linea[4],linea[5],linea[6])
      
      Antiguedad = 2020 - trabajador.get_anio_ingreso()
      AuxHE = float(trabajador.get_horas_extra())
      paga_extra = (276.5 * AuxHE)
      if ( Antiguedad > 0):
       Bono = (trabajador.get_salario_base()*0.03*Antiguedad)
       FinalSueldo = (trabajador.get_salario_base()) + Bono + paga_extra
       print(f"El salario de: {trabajador.get_nombres()} {trabajador.get_apellido_paterno()} {trabajador.get_apellido_materno()} es de {FinalSueldo}")
       
      else:
        FinalSueldo = (trabajador.get_salario_base()) + paga_extra
        print(f"El salario de: {trabajador.get_nombres()} {trabajador.get_apellido_paterno()} {trabajador.get_apellido_materno()} es de {FinalSueldo}")

    for linea in lineas:
      linea = linea.split(',')
      linea[0] = int(linea[0])
      linea[4] = int(linea[4])
      linea[5] = int(linea[5])
      anio = linea[6]
      anio = int(anio)
      linea[6] = anio
      numeros_trabajadores.append(linea[0])
      trabajador1 = empleado(linea[0],linea[1],linea[2],linea[3],linea[4],linea[5],linea[6])
      au = trabajador1.get_anio_ingreso()
      if (au == 2020):
       print(f"{trabajador1.get_nombres()} {trabajador1.get_apellido_paterno()} {trabajador1.get_apellido_materno()} es el empleado de menor antiguedad")

# %%
class Sueldos:
    def __init__(self):
        self.__data= None

    def cargar_datos(self, ruta_archivo):
        archivo = open(ruta_archivo, 'rt', encoding='latin1')
        cabeceras=archivo.readline()
        lineas= archivo.readlines()
        archivo.close()
        self.__data=Array( len(lineas) -1)
        #tarea
        numeros_trabajadores= []

        for linea in lineas:
            linea = linea.split(',')
            linea[0] = int(linea[0])
            linea[4] = int(linea[4])
            linea[5] = int(linea[5])
            anio = linea[6]
            anio = int(anio)
            linea[6] = anio

            numeros_trabajadores.append(linea[0])
      
            #crear un objeto
            trabajador = empleado(linea[0],linea[1],linea[2],linea[3],linea[4],linea[5],linea[6])

            antiguedad = 2020 - trabajador.get_anio_ingreso()
      
            HE = float(trabajador.get_horas_extra())
            horas_bonus = (276.5 * HE)
            if ( antiguedad > 0):
                Bono = (trabajador.get_salario_base()*0.03 * antiguedad)
                sueldo_final = (trabajador.get_salario_base()) + Bono + horas_bonus
                print(f"El salario de: {trabajador.get_nombres()} {trabajador.get_apellido_paterno()} {trabajador.get_apellido_materno()} es de {sueldo_final}")

            else:
                sueldo_final = (trabajador.get_salario_base()) + horas_bonus
                print(f"El salario de: {trabajador.get_nombres()} {trabajador.get_apellido_paterno()} {trabajador.get_apellido_materno()} es de {sueldo_final}")
     
        for linea in lineas:
            linea = linea.split(',')
            linea[0] = int(linea[0])
            linea[4] = int(linea[4])
            linea[5] = int(linea[5])
            anio = linea[6]
            anio = int(anio)
            linea[6] = anio
            numeros_trabajadores.append(linea[0])
            trabajador1 = empleado(linea[0],linea[1],linea[2],linea[3],linea[4],linea[5],linea[6])
            au = trabajador1.get_anio_ingreso()
            if (au == 2020):
                print(f"{trabajador1.get_nombres()} {trabajador1.get_apellido_paterno()} {trabajador1.get_apellido_materno()} es el empleado de menor antiguedad")
            if (au == 2016):
                print(f"{trabajador1.get_nombres()} {trabajador1.get_apellido_paterno()} {trabajador1.get_apellido_materno()} es el empleado de mayor antiguedad")
resultado = Sueldos()
resultado.cargar_datos('junio.dat')
# Out:
# El salario de: CARLOS PEREZ CASTILLO es de 10736.5
# El salario de: ANGEL GOMEZ GARRIDO es de 10126.5
# El salario de: JESUS MARTIN SANTOS es de 11585.0
# El salario de: DAVID JIMENEZ LOZANO es de 11289.5
# El salario de: PEDRO RUIZ GUERRERO es de 11289.5
# El salario de: DANIEL HERNANDEZ CANO es de 11270.5
# El salario de: ALEJANDRO DIAZ PRIETO es de 10994.0
# El salario de: MARIA MORENO MENDEZ es de 10717.5
# El salario de: ALBERTO MUOZ CRUZ es de 11013.0
# El salario de: RAFAEL ALVAREZ FLORES es de 11289.5
# El salario de: FERNANDO ROMERO HERRERA es de 11251.5
# El salario de: PABLO ALONSO GALLEGO es de 10422.0
# El salario de: JORGE GUTIERREZ MARQUEZ es de 10403.0
# El salario de: RAMON NAVARRO LEON es de 11308.5
# ANGEL GOMEZ GARRIDO es el empleado de menor antiguedad
# JESUS MARTIN SANTOS es el empleado de mayor antiguedad
# JORGE GUTIERREZ MARQUEZ es el empleado de menor antiguedad
# RAMON NAVARRO LEON es el empleado de mayor antiguedad
